# %% [markdown]
# ### Python for Statistiacal Learning
#     - Instructor: Prof. Varun Rai
#     - TA: Vivek Khetan
#     - Office Hours: Friday, 9:30 am - 11:30 am (or by appointment)

# %% [markdown]
# ###### Everyone should have python 3.x and jupyter notebook installed also the latest vesion of pandas, numpy, sklearn & matplotlib

# %% [markdown]
# ### What we are going to do:
# - `Basic Operations in Python`
# - `Important Data-Structure`
# - `Data loading/cleaning/slicing with pandas`
# - `Regression Models with sklearn`

# %%
# can do almost anything here interactively
2+3
# Out:
# 5

# %%
ans = 2+3
print(ans)
# Out:
# 5

# %% [markdown]
# #### Python Data Structures:
#     - List
#     - Strings
#     - Tuples
#     - Dictionary

# %% [markdown]
# #### Lists:
#     A list can simply be defined by writing a list of comma separated values in square brackets. Lists might contain items of different types, but usually the items all have the same type. Python lists are mutable and individual elements of a list can be changed.

# %%
my_list = [0,2,4,6,8,10]

# %% [markdown]
# Individual elements of a list can be accessed by writing the index number in sqr bracket

# %%
my_list[0]
# Out:
# 0

# %%
my_list[5] # index returns the item
# Out:
# 10

# %% [markdown]
# A range of script can be accessed by having first index and last index

# %%
my_list[2:6]# slicing return a new list
# Out:
# [4, 6, 8, 10]

# %% [markdown]
# can access the list from the end using negative index

# %%
my_list[-2]# should return the second last element of the list
# Out:
# 8

# %%
my_list[4 ] = 100
my_list
# Out:
# [0, 2, 4, 6, 100, 10]

# %% [markdown]
# ### Strings:
# - Strings can simply be defined by use of single ( ‘ ), double ( ” ) or triple ( ”’ ) inverted commas.
# - Strings enclosed in tripe quotes ( ”’ ) can span over multiple lines and are used frequently in docstrings (Python’s way of documenting functions).
# - Python strings are immutable,

# %%
greeting = "Hello Class"
print(greeting[2])
print(len(greeting))
print(greeting + " of 2018")
# Out:
# l
# 11
# Hello Class of 2018

# %% [markdown]
# ##### Python strings are immutable

# %%
greeting[1:] = "sorry about this"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0052b5dada86> in <module>()
# ----> 1 greeting[1:] = "sorry about this"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
#  - Other string methods include lower(), upper(), strip(), isdigit(), isspace(). find(), replace(), split() and join()
#  - useful in data manipulations and cleaning

# %% [markdown]
# #### Tuples
# - immutable
# - represented by a number of values seprated by commas

# %%
my_tuple = 0,1,4,9,16,25 # (0,1,4,9,16,25)

# %%
my_tuple
# Out:
# (0, 1, 4, 9, 16, 25)

# %%
my_tuple[4] # tuple elements can be accessed in similar fashion
# Out:
# 16

# %%
my_tuple[2] = 8 # tuples are immutable and hence this should result in error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d37dd8519246> in <module>()
# ----> 1 my_tuple[2] = 8 # tuples are immutable and hence this should result in error
#
# NameError: name 'my_tuple' is not defined

# %% [markdown]
# ### Dictinary
#  - an unordered set of key:value pairs
#  - keys are unique
#  - {} : to creates an empty dictionary

# %%
movies = {'james': 420, 'fastandfurious': 7, 'ironman': 4}

# %%
movies['avengers'] = 3
movies
# Out:
# {'avengers': 3, 'fastandfurious': 7, 'ironman': 4, 'james': 420}

# %%
movies.keys()
# Out:
# dict_keys(['james', 'fastandfurious', 'ironman', 'avengers'])

# %% [markdown]
# #### Python Iteration and Conditional Constructs

# %%
for i in range(7):
    print(i)
    print(i+6)
    print("-"*10)
# Out:
# 0
# 6
# ----------
# 1
# 7
# ----------
# 2
# 8
# ----------
# 3
# 9
# ----------
# 4
# 10
# ----------
# 5
# 11
# ----------
# 6
# 12
# ----------

# %%
10%2
# Out:
# 0

# %%
N = 10
if N%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
N = [2,3,6,10,13]
for i in N:
    if i%2 ==0:
        print("Even")
    else:
        print("Odd")
# Out:
# Even
# Odd
# Even
# Even
# Odd

# %% [markdown]
# ## Python Libraries: best thing about python
#   - `Numpy` : linear alzebra, n-dimetional array
#   - `scipy`: scientific python, built on top on numpy, linear alzebra, Optimization and matrix operation
#   - `Matplotlib` : all the plotting (%matplotlib --inline)
#   - `Pandas`: data munging and preparatin
#   - `Scikit Learn`: classification, regression, clustering and everything else
#   - `statsmodel`: statistical modeling

# %% [markdown]
# ### Numpy

# %%
import numpy as np

# %%
my_list = [2,5,4,7,9,11]

# %%
np.mean(my_list)
# Out:
# 6.333333333333333

# %%
np.median(my_list)
# Out:
# 6.0

# %%
np.array(4*3)
# Out:
# array(12)

# %%
np.array([4]*3)
# Out:
# array([4, 4, 4])

# %% [markdown]
# ### Pandas

# %% [markdown]
# 10 minutes to pandas # http://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
# !pip3 install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.DataFrame({ 'A' : 1.,
                         'B' : pd.Timestamp('20130102'),
                         'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                         'D' : np.array([3] * 4,dtype='int32'),
                         'E' : pd.Categorical(["test","train","test","train"]),
                         'F' : 'foo' })

# %%
df1
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
help(np.random.randn())
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x) -> floating point number
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(...)
#  |      float.__format__(format_spec) -> string
#  |
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getformat__(...) from builtins.type
# ...

# %%
# create a random dataset
df2 = pd.DataFrame(np.random.randn(10, 4))

df2
# Out:
#           0         1         2         3
# 0 -0.698963 -1.448598  0.556149  0.925535
# 1 -1.363751  0.450883 -1.066715 -0.140684
# 2  0.508117 -0.150259  0.927814 -2.212367
# 3 -2.586475 -0.151384  0.802033  1.626308
# 4 -1.063767 -0.308585 -0.255887  2.095647
# 5  0.262630  1.095488  1.270279  0.546439
# 6  0.780589  1.451773 -0.880000 -0.040009
# 7  2.131119  0.377180 -2.408269 -2.537159
# 8  1.104734  1.307886 -0.821448  0.695970
# 9 -0.710300  0.799845 -0.158562  0.098211

# %%
# read a csv file
df3 = pd.read_csv("titanic.csv")
# df.to_csv('foo.csv')

# %%
# !ls

# %%
df = df3.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# df.index

# %%
df.columns # list(df)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.sort_values(by = ["Age"], ascending = False)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 493          494         0       1
# 96            97         0       1
# 116          117         0       3
# 672          673         0       2
# 745          746         0       1
# 33            34         0       2
# 54            55         0       1
# 280          281         0       3
# 456          457         0       1
# 438          439         0       1
# 545          546         0       1
# 275          276         1       1
# 483          484         1       3
# 570          571         1       2
# 252          253         0       1
# 829          830         1       1
# 555          556         0       1
# 625          626         0       1
# 326          327         0       3
# 170          171         0       1
# 684          685         0       2
# 694          695         0       1
# 587          588         1       1
# ...

# %%
df[['Name']][:10] #df['Name'][:10]
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 351          352         0       1
# 394          395         1       3
# 724          725         1       1
# 496          497         1       1
# 228          229         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 351             Williams-Lambert, Mr. Fletcher Fellows    male   NaN      0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 724                      Chambers, Mr. Norman Campbell    male  27.0      1
# 496                     Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 228                          Fahlstrom, Mr. Arne Jonas    male  18.0      0
#
#      Parch   Ticket     Fare Cabin Embarked
# 351      0   113510  35.0000  C128        S
# 394      2  PP 9549  16.7000    G6        S
# 724      0   113806  53.1000    E8        S
# 496      0    36947  78.2667   D20        C
# 228      0   236171  13.0000   NaN        S

# %%
df[3:6] # get first three rows
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q

# %% [markdown]
# ### selection by label

# %%
df.loc[:,['Sex', 'Age']][:10]
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# 8  female  27.0
# 9  female  14.0

# %%
df.loc[[0,1,3], ["Name", "survived"]] #df.loc[[0,1,3], ["Name", "Survived"]]
# Out:
# /Users/vivek/.virtualenvs/lab_session/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                                                 Name  survived
# 0                            Braund, Mr. Owen Harris       NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       NaN

# %%
df.loc[2, 'Age'] # getting a scalar value
# Out:
# 26.0

# %% [markdown]
# ## Selection by position

# %%
df.iloc[3]#3rd row element
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df.iloc[3:5, 0:2] # row, column
# Out:
#    PassengerId  Survived
# 3            4         1
# 4            5         0

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#    PassengerId  Pclass
# 1            2       1
# 2            3       3
# 4            5       3

# %%
df.iloc[1:3, :] # slicing rows explicitly
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[:, 1:3] # slicing columns explicitly
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# 5           0       3
# 6           0       1
# 7           0       3
# 8           1       3
# 9           1       2
# 10          1       3
# 11          1       1
# 12          0       3
# 13          0       3
# 14          0       3
# 15          1       2
# 16          0       3
# 17          1       2
# 18          0       3
# 19          1       3
# 20          0       2
# 21          1       2
# 22          1       3
# 23          1       1
# 24          0       3
# 25          1       3
# 26          0       3
# 27          0       1
# 28          1       3
# 29          0       3
# ..        ...     ...
# 861         0       2
# 862         1       1
# 863         0       3
# 864         0       2
# 865         1       2
# 866         1       2
# 867         0       1
# 868         0       3
# 869         1       3
# ...

# %%
df.iloc[1,1]# get a value explicitly
# Out:
# 1

# %% [markdown]
# ## boolean Indexing

# %%
df[df.Age > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 124          125         0       1
# 150          151         0       2
# 152          153         0       3
# 155          156         0       1
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 222          223         0       3
# 232          233         0       2
# 249          250         0       2
# 252          253         0       1
# 262          263         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 317          318         0       2
# 326          327         0       3
# ...

# %% [markdown]
# ## missing data

# %%
df.dropna(how = "any")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df.fillna(value = 5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.fillna(value = 'what?')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
pd.isna(df)
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
## stats
df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
# df.mean(1) # operation on other axis

# %%
# !paip install sklearn
# !pip install scipy
import sklearn
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
from sklearn import linear_model
# Out:
# /Users/vivek/.virtualenvs/lab_session/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = df.dropna(how = 'any')

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
my_x = df[['Age']]  #df[['Age','Pclass', 'Parch', 'Fare']]
my_x.head()
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
my_y = df[["Survived"]]
my_y.sample(4)
# Out:
#      Survived
# 40          0
# 683         0
# 25          1
# 427         1

# %%
X_train, X_test, y_train, y_test = train_test_split(my_x, my_y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-36075a95e281> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(my_x, my_y, test_size=0.2)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ### Linear Regression Model

# %%
# Create linear regression object
first_regr = linear_model.LinearRegression()
model2 = linear_model.LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-3e9995384966> in <module>()
#       1 # Create linear regression object
# ----> 2 first_regr = linear_model.LinearRegression()
#       3 model2 = linear_model.LogisticRegression()
#
# NameError: name 'linear_model' is not defined

# %%
# Train the model using the training sets
first_regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-5708ff1262bd> in <module>()
#       1
#       2 # Train the model using the training sets
# ----> 3 first_regr.fit(X_train, y_train)
#
# NameError: name 'first_regr' is not defined

# %%
# The coefficients
print('Coefficients: \n', first_regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-9abd866a9920> in <module>()
#       1
#       2 # The coefficients
# ----> 3 print('Coefficients: \n', first_regr.coef_)
#
# NameError: name 'first_regr' is not defined

# %%
first_regr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-6a3d3d831b05> in <module>()
# ----> 1 first_regr.predict(X_test)
#
# NameError: name 'first_regr' is not defined

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((first_regr.predict(X_test) - y_test) ** 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-69bd365acdb5> in <module>()
#       1 # The mean squared error
#       2 print("Mean squared error: %.2f"
# ----> 3       % np.mean((first_regr.predict(X_test) - y_test) ** 2))
#
# NameError: name 'first_regr' is not defined

# %%
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % first_regr.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-c370c524c21c> in <module>()
#       1 # Explained variance score: 1 is perfect prediction
# ----> 2 print('Variance score: %.2f' % first_regr.score(X_test, y_test))
#
# NameError: name 'first_regr' is not defined

# %%
# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, first_regr.predict(X_test), color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ### Logistic Regression Model

# %%
model2.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-67f482719d15> in <module>()
# ----> 1 model2.fit(X_train, y_train)
#       2
#
# NameError: name 'model2' is not defined

# %%
# The coefficients
print('Coefficients: \n', model2.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-c2f673314924> in <module>()
#       1 # The coefficients
# ----> 2 print('Coefficients: \n', model2.coef_)
#       3
#
# NameError: name 'model2' is not defined

# %%
# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, model2.predict(X_test), color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-ecd829237e34> in <module>()
#       1
#       2 # Plot outputs
# ----> 3 plt.scatter(X_test, y_test,  color='black')
#       4 plt.plot(X_test, model2.predict(X_test), color='blue', linewidth=3)
#       5
#
# NameError: name 'X_test' is not defined
